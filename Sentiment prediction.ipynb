# %%
import nltk
nltk.download('twitter_samples')
nltk.download('movie_reviews')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
from nltk.corpus import twitter_samples
from nltk.tag import pos_tag

# %%
positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')
tweet_tokens = twitter_samples.tokenized('positive_tweets.json')[0]

# %%
print(tweet_tokens[0])
# Out:
# #FollowFriday

# %%
from nltk.stem.wordnet import WordNetLemmatizer

def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

print(lemmatize_sentence(tweet_tokens[0]))
# Out:
# ['#', 'F', 'o', 'l', 'l', 'o', 'w', 'F', 'r', 'i', 'd', 'a', 'y']

# %%
import re, string

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

#print(remove_noise(tweet_tokens[0], stop_words))

positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
print(positive_tweet_tokens[500])
print(positive_cleaned_tokens_list[500])
# Out:
# ['Dang', 'that', 'is', 'some', 'rad', '@AbzuGame', '#fanart', '!', ':D', 'https://t.co/bI8k8tb9ht']
# ['dang', 'rad', '#fanart', ':d']

# %%
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)

# %%
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
import random

positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
# from nltk import classify
# from nltk import NaiveBayesClassifier
# classifier = NaiveBayesClassifier.train(train_data)

# print("Accuracy is:", classify.f1score(classifier, test_data))

# print(classifier.show_most_informative_features(100))

# %%
from nltk.tokenize import word_tokenize

custom_tweet = "Deepak is a bully"

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# neg

# %%
train_data
# Out:
# [({'assignment': True, 'project': True, ':(': True, 'really': True, '😩': True},
#   'Negative'),
#  ({'love': True, 'u': True, ':p': True}, 'Positive'),
#  ({'happy': True, 'birthday': True, 'hajur': True, ':)': True}, 'Positive'),
#  ({'mean': True,
#    'low': True,
#    'limit': True,
#    'table': True,
#    'xd': True,
#    ':(': True},
#   'Negative'),
#  ({'brendon': True, "urie's": True, 'suit': True, 'game': True, ':(': True},
#   'Negative'),
#  ({'land': True,
#    'gc': True,
#    'yeeew': True,
#    'pre': True,
#    'lan': True,
#    ':)': True},
#   'Positive'),
#  ({'tonight': True,
#    'night': True,
#    '...': True,
#    ':)': True,
#    '#nuka': True,
#    '#penacova': True,
#    '#djset': True,
#    '#free': True,
#    '#edm': True,
#    '#kizomba': True,
#    '#latinhouse': True,
#    '#housemusic': True,
#    '#portugal2015': True,
#    '#summer': True},
#   'Positive'),
#  ({'great': True,
#    'thanks': True,
#    'lovely': True,
#    ':-)': True,
#    'almost': True,
#    '40': True,
#    'response': True,
#    'first': True,
#    'hour': True,
#    'delighted': True,
#    'really': True,
#    'comment': True,
#    'next': True},
#   'Positive'),
#  ({'6:15': True, "i'm": True, 'wide': True, 'awake': True, ':(': True},
#   'Negative'),
#  ({'nakakapikon': True,
#    'yung': True,
#    'nagbabasa': True,
#    'ka': True,
#    'ng': True,
#    'blog': True,
#    'comment': True,
#    'info': True,
#    'full': True,
#    'people': True,
#    'ask': True,
#    'damned': True,
#    'question': True,
#    'answer': True,
#    'post': True,
#    ':(': True},
#   'Negative'),
#  ({'get': True, 'pace': True, 'maker': True, 'oh': True, ':(': True},
#   'Negative'),
#  ({'know': True,
#    'help': True,
#    'get': True,
#    'awake': True,
#    '...': True,
#    'shock': True,
#    'spill': True,
#    'coffe': True,
#    'rest': True,
#    ':d': True},
#   'Positive'),
#  ({'...': True, 'cup': True, 'empty': True, ':d': True}, 'Positive'),
#  ({'work': True,
#    'long': True,
#    'really': True,
#    'doable': True,
#    'drive': True,
#    'train': True,
#    'awful': True,
#    'moved': True,
#    'agency': True,
#    'story.miss': True,
#    'everone': True,
#    'though': True,
#    ':(': True,
#    'r': True,
#    'u': True,
#    'ok': True,
#    'x': True},
#   'Negative'),
#  ({'hi': True,
#    'emma': True,
#    ':-)': True,
#    'ask': True,
#    '#bellybutton': True,
#    '#innie': True,
#    '#outie': True},
#   'Positive'),
#  ({'welcome': True, ':d': True}, 'Positive'),
#  ({'want': True, 'win': True, 'today': True, ':(': True}, 'Negative'),
#  ({"i'm": True,
#    'stefanie': True,
#    '...': True,
#    'real': True,
#    'one': True,
#    ':)': True},
#   'Positive'),
#  ({'#fallout4': True,
#    'get': True,
#    'see': True,
#    'glowing': True,
#    'sea': True,
#    'technically': True,
#    'fallout': True,
#    '3': True,
#    'play': True,
#    ':d': True},
#   'Positive'),
#  ({'read': True, ':)': True, '#kunoriforceo': True, '#ceo1month': True},
#   'Positive'),
#  ({'rain': True, ':(': True}, 'Negative'),
#  ({'aw': True,
#    ':-(': True,
#    'depends': True,
#    'define': True,
#    'success': True,
#    'good': True,
#    'music': True,
#    '2': True,
#    "i'd": True,
#    'say': True,
#    'successful': True},
#   'Negative'),
#  ({'miss': True, 'already': True, ':-(': True}, 'Negative'),
#  ({'guy': True, 'great': True, 'weekend': True, ':)': True}, 'Positive'),
#  ({'wanna': True, 'watch': True, 'paper': True, 'towns': True, ':-(': True},
#   'Negative'),
#  ({'yes': True,
#    'unfortunately': True,
#    'whole': True,
#    'troubleshooting': True,
#    'box': True,
#    "i'm": True,
#    'still': True,
#    'issue': True,
#    ':(': True},
#   'Negative'),
#  ({'sticker': True,
#    'come': True,
#    'sponsor': True,
#    'prize': True,
#    'entry': True,
#    'tablet': True,
#    ':)': True},
#   'Positive'),
#  ({'happy': True, 'friday': True, ':-)': True}, 'Positive'),
#  ({'holy': True,
#    'fuck': True,
#    'u': True,
#    'okay': True,
#    'text': True,
#    'need': True,
#    'anythin': True,
#    ':-(': True},
#   'Negative'),
#  ({'thanks': True,
#    'zy': True,
#    "let's": True,
#    'friend': True,
#    'yaa': True,
#    ':)': True},
#   'Positive'),
#  ({'think': True,
#    'could': True,
#    'hug': True,
#    'right': True,
#    ':(': True,
#    'poor': True,
#    'thing': True,
#    'sent': True,
#    'dm': True,
#    'interested': True,
#    'hope': True,
#    'get': True,
#    'good': True,
#    'soon': True},
#   'Negative'),
#  ({':)': True}, 'Positive'),
#  ({'expect': True,
#    'unexpect': True,
#    '...': True,
#    ':(': True,
#    '#bestfriend': True},
#   'Negative'),
#  ({'first': True, 'impression': True, ':)': True}, 'Positive'),
#  ({':-(': True}, 'Negative'),
#  ({'..': True,
#    'buti': True,
#    'thought': True,
#    'ure': True,
#    'poop': True,
#    'friend': True,
#    ':(': True},
#   'Negative'),
#  ({'freaking': True, 'cat': True, 'cuddle': True, ':-(': True}, 'Negative'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '7': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'process': True,
#    'list': True,
#    'feature': True,
#    'mostly': True,
#    "cinema's": True,
#    ':)': True},
#   'Positive'),
#  ({'give': True,
#    'sunburnt': True,
#    'manage': True,
#    'get': True,
#    'weekend': True,
#    'maybe': True,
#    "i'll": True,
#    'safer': True,
#    'rain': True,
#    ':(': True},
#   'Negative'),
#  ({'congrats': True, 'us': True, ':d': True}, 'Positive'),
#  ({'happy': True, 'friday': True, ':-)': True}, 'Positive'),
#  ({'snapchat': True,
#    'amargolonnard': True,
#    '#snapchat': True,
#    '#kikhorny': True,
#    '#snapme': True,
#    '#tagsforlikes': True,
#    '#batalladelosgallos': True,
#    '#webcamsex': True,
#    ':(': True},
#   'Negative'),
#  ({'haha': True, 'bed': True, 'cake': True, ':(': True}, 'Negative'),
#  ({'twitter': True,
#    'turn': True,
#    'much': True,
#    'complicate': True,
#    "can't": True,
#    'find': True,
#    'trend': True,
#    ':(': True},
#   'Negative'),
#  ({'everyone': True,
#    'want': True,
#    'parcel': True,
#    'willing': True,
#    'believe': True,
#    'auspost': True,
#    'fail': True,
#    'deliver': True,
#    ':)': True},
#   'Positive'),
#  ({'new': True, 'bio': True, 'bodo': True, 'amat': True, ':-(': True},
#   'Negative'),
#  ({'jacob': True, 'g': True, 'upgrade': True, ':-)': True}, 'Positive'),
#  ({'ah': True,
#    'guy': True,
#    'know': True,
#    'thing': True,
#    'weather': True,
#    'set': True,
#    'sleep': True,
#    'responsibility': True,
#    ':-(': True},
#   'Negative'),
#  ({'mean': True,
#    'already': True,
#    'dream': True,
#    'come': True,
#    'true': True,
#    'notice': True,
#    'thats': True,
#    'enough': True,
#    ':)': True},
#   'Positive'),
#  ({'nvm': True,
#    'lemme': True,
#    'quiet': True,
#    'eat': True,
#    'foof': True,
#    ':(': True},
#   'Negative'),
#  ({'good': True, 'morning': True, ':)': True}, 'Positive'),
#  ({'love': True, ':d': True}, 'Positive'),
#  ({"mum's": True,
#    'home': True,
#    '...': True,
#    'hahahhaah': True,
#    'thank': True,
#    'lord': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True,
#    "can't": True,
#    'wait': True,
#    'make': True,
#    'next': True,
#    'cover': True,
#    ':)': True},
#   'Positive'),
#  ({'im': True,
#    'get': True,
#    'ollys': True,
#    'tweet': True,
#    'notification': True,
#    ':(': True},
#   'Negative'),
#  ({'forget': True, 'get': True, 'pale': True, 'foundation': True, ':(': True},
#   'Negative'),
#  ({'aint': True,
#    'never': True,
#    'uploading': True,
#    'lol': True,
#    'also': True,
#    'find': True,
#    'another': True,
#    'vid': True,
#    'u': True,
#    'dance': True,
#    'henrys': True,
#    'trap': True,
#    'keep': True,
#    'go': True,
#    'fitness': True,
#    'journey': True,
#    'tommy': True,
#    ':)': True},
#   'Positive'),
#  ({'lyka': True, 'followback': True, ':)': True}, 'Positive'),
#  ({'konga': True,
#    'well': True,
#    '...': True,
#    'ni': True,
#    'wa': True,
#    'ode': True,
#    'e': True,
#    'k': True,
#    'need': True,
#    'disvirgined': True,
#    '..': True,
#    'like': True,
#    'seriously': True,
#    ':(': True},
#   'Negative'),
#  ({'reign': True,
#    'error': True,
#    'example': True,
#    'inflation': True,
#    'rate': True,
#    'sic': True,
#    ':(': True},
#   'Negative'),
#  ({'real': True, 'trick': True, 'shot': True, ':)': True}, 'Positive'),
#  ({"they've": True, 'cut': True, 'pant': True, 'incident': True, ':(': True},
#   'Negative'),
#  ({'gyu': True,
#    'r': True,
#    'u': True,
#    'cute': True,
#    ':-(': True,
#    'hurt': True,
#    'ok': True},
#   'Negative'),
#  ({'know': True,
#    'live': True,
#    'australia': True,
#    'talk': True,
#    'friend': True,
#    'cuz': True,
#    'like': True,
#    '4am': True,
#    'thanks': True,
#    'anyway': True,
#    ':)': True},
#   'Positive'),
#  ({'miss': True,
#    '5sos': True,
#    'much': True,
#    'cant': True,
#    'deal': True,
#    'wait': True,
#    'possibly': True,
#    'year': True,
#    'see': True,
#    ':(': True},
#   'Negative'),
#  ({'thank': True, ':)': True, 'x': True}, 'Positive'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'#tracerequest': True, 'good': True, 'selena': True, ':)': True},
#   'Positive'),
#  ({'add': True, ':)': True}, 'Positive'),
#  ({'yoohoo': True,
#    'shattering': True,
#    'record': True,
#    '#bajrangibhaijaanstorm': True,
#    '#superhappy': True,
#    ':d': True},
#   'Positive'),
#  ({'yummmyyy': True,
#    '...': True,
#    ':-)': True,
#    '—': True,
#    'eat': True,
#    'dosa': True},
#   'Positive'),
#  ({'add': True,
#    'snapchat': True,
#    'nicoleapage': True,
#    '#snapchat': True,
#    '#kiksex': True,
#    '#kikmeboys': True,
#    '#makeup': True,
#    '#free': True,
#    '#camsex': True,
#    ':(': True},
#   'Negative'),
#  ({'project': True,
#    'want': True,
#    'enter': True,
#    '#pitchwars': True,
#    'may': True,
#    'work': True,
#    ':(': True,
#    'first': True,
#    'chap': True,
#    "mine's": True,
#    'phone': True,
#    'call': True,
#    'transcript': True,
#    '#ugh': True},
#   'Negative'),
#  ({'🌞': True, ':)': True, 'stay': True, 'perfect': True, 'girly': True},
#   'Positive'),
#  ({'missing': True, 'best': True, 'friend': True, ':(': True}, 'Negative'),
#  ({'diz': True,
#    'personal': True,
#    'account': True,
#    'also': True,
#    'fan': True,
#    'acc': True,
#    'link': True,
#    'bioooo': True,
#    ':-(': True,
#    'ay': True,
#    'taray': True,
#    'yumu-youtuber': True},
#   'Negative'),
#  ({'oh': True,
#    'really': True,
#    'wonder': True,
#    'expensive': True,
#    ':(': True,
#    'u': True,
#    'donating': True},
#   'Negative'),
#  ({'cooper': True,
#    "i'm": True,
#    'convince': True,
#    'neither': True,
#    '2': True,
#    'please': True,
#    'concerned': True,
#    'creasy': True,
#    'win': True,
#    'deputy': True,
#    ':(': True},
#   'Negative'),
#  ({'cheer': True, ':)': True}, 'Positive'),
#  ({'lil': True,
#    'bitch': True,
#    'heiya': True,
#    'visit': True,
#    'site': True,
#    'u': True,
#    'wanna': True,
#    'grab': True,
#    'free': True,
#    '30.000': True,
#    '8': True,
#    'ball': True,
#    'pool': True,
#    'coins': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({'would': True,
#    'love': True,
#    'see': True,
#    'w': True,
#    'nick': True,
#    'pick': True,
#    'one': True,
#    'waisted': True,
#    'tv': True,
#    'time': True,
#    'never': True,
#    'work': True,
#    'anyway': True,
#    ':(': True},
#   'Negative'),
#  ({'guys': True, 'nooooo': True, ':-(': True, 'wow': True}, 'Negative'),
#  ({'nice': True,
#    'see': True,
#    'people': True,
#    'change': True,
#    'need': True,
#    'fix': True,
#    'care': True,
#    ':)': True},
#   'Positive'),
#  ({'look': True,
#    'promise': True,
#    'evening': True,
#    'cricket': True,
#    ':(': True},
#   'Negative'),
#  ({'little': True, 'finger': True, ':d': True}, 'Positive'),
#  ({'thanks': True, 'lisa': True, ':)': True}, 'Positive'),
#  ({'find': True,
#    'late': True,
#    'sorry': True,
#    'ask': True,
#    'stupid': True,
#    'question': True,
#    'loving': True,
#    'plugin': True,
#    'far': True,
#    'also': True,
#    'love': True,
#    'bass': True,
#    'slap': True,
#    'ig': True,
#    'play': True,
#    ':)': True},
#   'Positive'),
#  ({'guy': True, ':(': True, '"saoloh': True}, 'Negative'),
#  ({'hour': True,
#    'beauty': True,
#    'sleep': True,
#    'ready': True,
#    'pure': True,
#    'organisation': True,
#    'offices': True,
#    'weekend': True,
#    ':-)': True,
#    'oh': True,
#    '...': True},
#   'Positive'),
#  ({'come': True, 'man': True, ':d': True}, 'Positive'),
#  ({'already': True,
#    'afternoon': True,
#    'let': True,
#    'read': True,
#    'al': True,
#    'kahfi': True,
#    'day': True,
#    'finish': True,
#    ':)': True},
#   'Positive'),
#  ({"can't": True,
#    'sleep': True,
#    'much': True,
#    'want': True,
#    'love': True,
#    'bug': True,
#    'make': True,
#    '33': True,
#    'token': True,
#    'never': True,
#    'mind': True,
#    ':)': True},
#   'Positive'),
#  ({'happy': True, 'friday': True, ':d': True}, 'Positive'),
#  ({'idea': True,
#    ':d': True,
#    '#sunjam': True,
#    'hope': True,
#    'rip': True,
#    'people': True,
#    'process': True,
#    'cough': True},
#   'Positive'),
#  ({'dear': True,
#    'please': True,
#    'ask': True,
#    'paperboy': True,
#    'keep': True,
#    'paper': True,
#    'rain': True,
#    'today': True,
#    'special': True,
#    'issue': True,
#    ':-)': True},
#   'Positive'),
#  ({'ha': True,
#    'talk': True,
#    'course': True,
#    '...': True,
#    'one': True,
#    'virtual': True,
#    'variety': True,
#    ':)': True},
#   'Positive'),
#  ({'free': True,
#    '#über': True,
#    'ice': True,
#    'cream': True,
#    'big': True,
#    'gay': True,
#    'al': True,
#    'today': True,
#    'really': True,
#    'want': True,
#    'anyway': True,
#    ':(': True,
#    '…': True},
#   'Negative'),
#  ({'saturday': True, ':)': True}, 'Positive'),
#  ({'kik': True,
#    'hearess': True,
#    '677': True,
#    '#kik': True,
#    '#kikhorny': True,
#    '#hornykik': True,
#    '#babe': True,
#    '#chat': True,
#    '#countrymusic': True,
#    '#txt_shot': True,
#    ':(': True},
#   'Negative'),
#  ({'hi': True,
#    'great': True,
#    'connect': True,
#    'specialise': True,
#    'thermal': True,
#    'image': True,
#    'survey': True,
#    '–': True,
#    'need': True,
#    'us': True,
#    ':)': True},
#   'Positive'),
#  ({'payback': True,
#    'like': True,
#    'video': True,
#    'try': True,
#    'help': True,
#    'get': True,
#    'kit': True,
#    'kat': True,
#    ':(': True},
#   'Negative'),
#  ({'love': True,
#    'goodnight': True,
#    'vid': True,
#    'go': True,
#    'wake': True,
#    'one': True,
#    ':)': True},
#   'Positive'),
#  ({'yes': True,
#    'please': True,
#    'would': True,
#    'great': True,
#    'work': True,
#    ':d': True,
#    '#peachyloans': True,
#    '#fridayfreebie': True,
#    'xx': True},
#   'Positive'),
#  ({':(': True, 'cold': True, 'never': True, 'bother': True, 'anyway': True},
#   'Negative'),
#  ({'miss': True,
#    'hannah': True,
#    'montana': True,
#    "that's": True,
#    'raven': True,
#    'sooo': True,
#    'much': True,
#    ':-(': True},
#   'Negative'),
#  ({'ph': True,
#    'vip': True,
#    'next': True,
#    'week': True,
#    'na': True,
#    ':(': True},
#   'Negative'),
#  ({'’': True, 'thesis': True, ':(': True}, 'Negative'),
#  ({'c': True, 'note': True, ':)': True, '#pkwalasawaal': True}, 'Positive'),
#  ({'go': True,
#    'outlying': True,
#    'island': True,
#    'cheung': True,
#    'chau': True,
#    'mui': True,
#    'wo': True,
#    '...': True,
#    'totally': True,
#    'different': True,
#    ':)': True},
#   'Positive'),
#  ({'girlll': True,
#    'u': True,
#    'hear': True,
#    'abt': True,
#    'possibly': True,
#    'tsunami': True,
#    'us': True,
#    'west': True,
#    'indies': True,
#    'im': True,
#    'island': True,
#    'afraid': True,
#    'lol': True,
#    ':(': True},
#   'Negative'),
#  ({'follow': True, 'back': True, 'thanks': True, 'please': True, ':(': True},
#   'Negative'),
#  ({'billie': True, ':-)': True, 'happen': True, 'arm': True}, 'Positive'),
#  ({'kina': True,
#    'best': True,
#    '..': True,
#    'love': True,
#    ':)': True,
#    'hi': True,
#    'donna': True,
#    'great': True,
#    'see': True,
#    'tonight': True},
#   'Positive'),
#  ({'foot': True, 'hurt': True, ':(': True}, 'Negative'),
#  ({'well': True,
#    'good': True,
#    'luck': True,
#    'anne': True,
#    'always': True,
#    'go': True,
#    'indie': True,
#    'route': True,
#    'joy': True,
#    ':)': True},
#   'Positive'),
#  ({"where's": True, 'black': True, 'magic': True, ':(': True}, 'Negative'),
#  ({"can't": True, 'retweet': True, 'stuff': True, ':(': True}, 'Negative'),
#  ({'yay': True,
#    'thankyou': True,
#    'bonding': True,
#    'ulit': True,
#    'soon': True,
#    ":')": True,
#    ':)': True},
#   'Positive'),
#  ({'reading': True, 'beautiful': True, 'like': True, 'read': True, ':)': True},
#   'Positive'),
#  ({'still': True,
#    'green': True,
#    'tea': True,
#    'blend': True,
#    'flavor': True,
#    ':)': True},
#   'Positive'),
#  ({'sure': True, 'sorry': True, ':(': True, 'x': True}, 'Negative'),
#  ({'jay': True,
#    'patrice': True,
#    'keepin': True,
#    'real': True,
#    'like': True,
#    'always': True,
#    ':)': True,
#    'mohr': True,
#    'stories': True,
#    'w': True,
#    'guest': True,
#    "o'neal": True,
#    'via': True},
#   'Positive'),
#  ({'wifi': True, 'steroid': True, 'today': True, ':d': True}, 'Positive'),
#  ({'download': True,
#    'uber': True,
#    'mobile': True,
#    'application': True,
#    'place': True,
#    'order': True,
#    ':)': True,
#    '#enjoy': True},
#   'Positive'),
#  ({'like': True, 'dog': True, ':(': True}, 'Negative'),
#  ({'#ourdaughtersourpride': True,
#    'dhan': True,
#    'satguru': True,
#    'tera': True,
#    'hi': True,
#    'aasra': True,
#    '...': True,
#    'many': True,
#    'congratulation': True,
#    'pita': True,
#    'g': True,
#    'keep': True,
#    'bless': True,
#    'always': True,
#    ':-)': True},
#   'Positive'),
#  ({'sad': True, 'view': True, ':(': True}, 'Negative'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    ':(': True,
#    'x15': True,
#    '340': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'wisdom': True,
#    'teeth': True,
#    'give': True,
#    'much': True,
#    'ache': True,
#    ':(': True},
#   'Negative'),
#  ({'yayyyy': True,
#    'hope': True,
#    'knock': True,
#    'anesthesia': True,
#    'sad': True,
#    'miss': True,
#    ':(': True},
#   'Negative'),
#  ({'cancel': True,
#    'ice': True,
#    'cream': True,
#    'uber': True,
#    'order': True,
#    'everyone': True,
#    'else': True,
#    'office': True,
#    'get': True,
#    ':(': True},
#   'Negative'),
#  ({'followed': True, 'thanks': True, 'please': True, ':(': True}, 'Negative'),
#  ({':)': True}, 'Positive'),
#  ({'live': True, 'summer': True, ':d': True}, 'Positive'),
#  ({'second': True, 'well': True, ':)': True}, 'Positive'),
#  ({'check': True,
#    'new': True,
#    'article': True,
#    'blog': True,
#    ':)': True,
#    'app': True,
#    'terrific': True},
#   'Positive'),
#  ({'point': True,
#    'yolo': True,
#    'sort': True,
#    'die': True,
#    'lactose': True,
#    '...': True,
#    'ugh': True,
#    'like': True,
#    '3': True,
#    'month': True,
#    'pregnant': True,
#    'bloating': True,
#    ':(': True},
#   'Negative'),
#  ({'super': True, ':d': True}, 'Positive'),
#  ({'free': True, 'twitter': True, ':(': True}, 'Negative'),
#  ({'tomorrow': True, 'lmao': True, 'hehe': True, ':d': True}, 'Positive'),
#  ({'good': True,
#    'man': True,
#    'shame': True,
#    'long': True,
#    'cigar': True,
#    'though': True,
#    ':(': True},
#   'Negative'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x26': True},
#   'Positive'),
#  ({'come': True,
#    'barcelona': True,
#    'year': True,
#    ':(': True,
#    'able': True,
#    'see': True,
#    'madrid': True,
#    'bilbao': True,
#    '...': True},
#   'Negative'),
#  ({"i'm": True, 'follow': True, ':)': True}, 'Positive'),
#  ({'ding': True, 'hundred': True, 'point': True, 'u': True, ':(': True},
#   'Negative'),
#  ({'quite': True,
#    'phenomenal': True,
#    'offer': True,
#    'bosch': True,
#    'washing': True,
#    'machine': True,
#    "week's": True,
#    'definitely': True,
#    'last': True,
#    'long': True,
#    ':)': True},
#   'Positive'),
#  ({'sooooooooo': True, 'happy': True, 'grade': True, ':d': True}, 'Positive'),
#  ({'goodafternoon': True, ':)': True, 'gudday': True}, 'Positive'),
#  ({'weird': True, ':(': True}, 'Negative'),
#  ({'finishing': True,
#    'monday': True,
#    'sadly': True,
#    ':(': True,
#    'close': True,
#    'beta': True,
#    'end': True,
#    'year': True},
#   'Negative'),
#  ({'like': True,
#    'see': True,
#    'sad': True,
#    ':(': True,
#    'smile': True,
#    'stay': True,
#    'strong': True,
#    'alright': True,
#    '😊': True,
#    '💞': True},
#   'Negative'),
#  ({'okay': True, '..': True, ':(': True}, 'Negative'),
#  ({'watching': True,
#    'abusive': True,
#    'relationship': True,
#    'video': True,
#    'fucking': True,
#    'hard': True,
#    "i'm": True,
#    'try': True,
#    'cry': True,
#    'like': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'go': True,
#    'please': True,
#    'click': True,
#    'link': True,
#    'checkout': True,
#    ':)': True},
#   'Positive'),
#  ({'lol': True, 'really': True, 'unlike': True, ':(': True}, 'Negative'),
#  ({'want': True,
#    'watch': True,
#    'movie': True,
#    'listen': True,
#    'sizwe': True,
#    'eat': True,
#    'write': True,
#    'assignment': True,
#    'time': True,
#    '...': True,
#    "can't": True,
#    ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'thank': True,
#    'u': True,
#    'oh': True,
#    'damn': True,
#    'hella': True,
#    'suck': True,
#    ':-(': True,
#    'least': True,
#    'really': True,
#    'good': True,
#    'time': True,
#    "that's": True,
#    'matter': True},
#   'Negative'),
#  ({"can't": True, 'go': True, 'ed': True, ':(': True}, 'Negative'),
#  ({'well': True,
#    'interesting': True,
#    'breakfast': True,
#    '…': True,
#    'back': True,
#    'holiday': True,
#    ':)': True},
#   'Positive'),
#  ({'thanks': True, ':-)': True}, 'Positive'),
#  ({'goodbye': True, 'ny': True, ':(': True, '🚖': True, '🗽': True, '🌃': True},
#   'Negative'),
#  ({'follow': True, 'instagram': True, ':d': True}, 'Positive'),
#  ({'refreshing': True,
#    'time': True,
#    'tirth': True,
#    'brambhatt': True,
#    ':d': True,
#    '—': True,
#    'playing': True,
#    'snooker': True},
#   'Positive'),
#  ({'thats': True, 'omg': True, 'imsorry': True, ':(': True}, 'Negative'),
#  ({'guess': True,
#    "y'all": True,
#    'ugly': True,
#    'asf': True,
#    'huh': True,
#    ':(': True},
#   'Negative'),
#  ({'stats': True,
#    'day': True,
#    'arrive': True,
#    '1': True,
#    'new': True,
#    'follower': True,
#    'unfollowers': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'friday': True,
#    'night': True,
#    'hong': True,
#    'kong': True,
#    '...': True,
#    'ferry': True,
#    'central': True,
#    'meet': True,
#    'new': True,
#    'girlfriend': True,
#    'after-work': True,
#    'drink': True,
#    ':-)': True},
#   'Positive'),
#  ({'sore': True, 'alice': True, ':(': True}, 'Negative'),
#  ({'point': True, ':)': True, '#marketing': True, '#branding': True},
#   'Positive'),
#  ({'know': True, "i'm": True, 'sorry': True, ':(': True}, 'Negative'),
#  ({'thanks': True, 'retweet': True, ':)': True}, 'Positive'),
#  ({'itty': True, 'bitty': True, 'teenie': True, 'bikini': True, ':)': True},
#   'Positive'),
#  ({'followed': True, 'thanks': True, 'please': True, ':(': True}, 'Negative'),
#  ({'hello': True,
#    ':)': True,
#    'get': True,
#    'youth': True,
#    'job': True,
#    'opportunities': True,
#    'follow': True},
#   'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'want': True, 'follow': True, ':(': True}, 'Negative'),
#  ({'jessica': True,
#    'call': True,
#    'quit': True,
#    'power': True,
#    'ab': True,
#    '5:15': True,
#    ':-(': True},
#   'Negative'),
#  ({'paper': True, 'girl': True, ':d': True}, 'Positive'),
#  ({'..': True,
#    'harry': True,
#    'dm': True,
#    'giveaway': True,
#    'nooow': True,
#    ':)': True,
#    '♥': True,
#    '★': True,
#    '☆': True},
#   'Positive'),
#  ({'apparently': True, 'isnt': True, ':(': True}, 'Negative'),
#  ({'hate': True, 'u': True, 'offline': True, ':(': True}, 'Negative'),
#  ({'dude': True, 'even': True, 'go': True, 'watch': True, ':(': True},
#   'Negative'),
#  ({'whaaaaaaat': True, 'noooooooo': True, ':(': True}, 'Negative'),
#  ({'chat': True,
#    'detail': True,
#    'project': True,
#    'inshallah': True,
#    ':)': True,
#    'ready': True,
#    ';)': True},
#   'Positive'),
#  ({'yeah': True, "i'm": True, ':(': True}, 'Negative'),
#  ({'follow': True, ':(': True}, 'Negative'),
#  ({'aha': True,
#    'yes': True,
#    'look': True,
#    'forward': True,
#    'see': True,
#    ':)': True},
#   'Positive'),
#  ({'offer': True, 'mixtape': True, 'talk': True, 'suckmejimin': True},
#   'Negative'),
#  ({'like': True,
#    '...': True,
#    'put': True,
#    'one': True,
#    'side': True,
#    'tell': True,
#    'staff': True,
#    'still': True,
#    'slot': True,
#    'make': True,
#    'look': True,
#    'untouched': True,
#    ':(': True},
#   'Negative'),
#  ({'mega': True, 'powers': True, 'expelled': True, ':-)': True}, 'Positive'),
#  ({'bad': True, ':(': True}, 'Negative'),
#  ({'fridays': True,
#    'mean': True,
#    '...': True,
#    'roller': True,
#    'skate': True,
#    'night': True,
#    ':)': True},
#   'Positive'),
#  ({'want': True, 'pete': True, 'wentz': True, ':(': True}, 'Negative'),
#  ({'see': True,
#    'ur': True,
#    'bio': True,
#    '😆': True,
#    'u': True,
#    'break': True,
#    'heart': True,
#    'actually': True,
#    ':(': True},
#   'Negative'),
#  ({'win': True, ':(': True}, 'Negative'),
#  ({'hp': True,
#    'cursed': True,
#    'child': True,
#    'book': True,
#    'play': True,
#    ':(': True},
#   'Negative'),
#  ({'free': True,
#    'slice': True,
#    'toast': True,
#    'every': True,
#    'large': True,
#    'coffee-weekdays': True,
#    '9-11': True,
#    '30': True,
#    ':)': True,
#    'ask': True,
#    'us': True,
#    'offer': True},
#   'Positive'),
#  ({'love': True, 'little': True, 'bit': True, ':-)': True}, 'Positive'),
#  ({'ya': True,
#    'dis': True,
#    'sound': True,
#    'lyk': True,
#    'gud': True,
#    'idea': True,
#    ':)': True},
#   'Positive'),
#  ({'#louisiana': True,
#    'cinema': True,
#    'shooting': True,
#    'mass': True,
#    'happen': True,
#    'regularly': True,
#    'us': True,
#    'sympathis': True,
#    'victim': True,
#    'family': True,
#    ':(': True},
#   'Negative'),
#  ({'9am': True, 'tearout': True, 'selektion': True, 'yoot': True, ':)': True},
#   'Positive'),
#  ({'bosen': True, ':(': True}, 'Negative'),
#  ({'might': True,
#    'worthwhile': True,
#    'endeavour': True,
#    ':-)': True,
#    'excuse': True,
#    'weekend': True,
#    'away': True},
#   'Positive'),
#  ({'twitter': True,
#    'buddy': True,
#    'able': True,
#    '5': True,
#    'minute': True,
#    'transparency': True,
#    'job': True,
#    'shit': True,
#    'photoshop': True,
#    ':(': True},
#   'Negative'),
#  ({'ill': True, 'bad': True, ':(': True}, 'Negative'),
#  ({'awww': True,
#    'miss': True,
#    'swear': True,
#    'twitter': True,
#    'day': True,
#    'truly': True,
#    'bore': True,
#    'rather': True,
#    'watch': True,
#    'movie': True,
#    'football': True,
#    ':(': True},
#   'Negative'),
#  ({'bet': True,
#    'excited': True,
#    ':)': True,
#    ":')": True,
#    'xxxxxxx': True,
#    'good': True,
#    'luck': True,
#    'hope': True,
#    'get': True,
#    'number': True,
#    'one': True},
#   'Positive'),
#  ({'good': True,
#    'news': True,
#    'boaz': True,
#    'myhill': True,
#    'front': True,
#    'takeover': True,
#    ':-(': True,
#    '#wba': True},
#   'Negative'),
#  ({'p': True,
#    '£': True,
#    'heiya': True,
#    'visit': True,
#    'site': True,
#    'u': True,
#    'wanna': True,
#    'grab': True,
#    'free': True,
#    '30.000': True,
#    '8': True,
#    'ball': True,
#    'pool': True,
#    'coins': True,
#    'thank': True,
#    ':)': True},
#   'Positive'),
#  ({':)': True, 'day': True, 'tommorow': True, 'ok': True, 'chill': True},
#   'Positive'),
#  ({"i've": True,
#    'move': True,
#    'australia': True,
#    'matter': True,
#    'time': True,
#    ':(': True},
#   'Negative'),
#  ({'ahh': True, 'fam': True, ':(': True, '#respectlost': True}, 'Negative'),
#  ({'#dishoom': True,
#    'make': True,
#    'way': True,
#    '#rajnigandha': True,
#    ':)': True,
#    '3': True,
#    'day': True,
#    'go': True,
#    'share': True,
#    'u': True,
#    'version': True,
#    'beautiful': True,
#    '#song': True},
#   'Positive'),
#  ({'want': True,
#    'froze': True,
#    'chocolate': True,
#    'cover': True,
#    'banana': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True, 'pretzel': True, ':(': True, '#bb17': True, '#bblf': True},
#   'Negative'),
#  ({'say': True,
#    'want': True,
#    'lucy': True,
#    'go': True,
#    'soon': True,
#    'lisa': True,
#    'oh': True,
#    "that's": True,
#    'horrible': True,
#    'sorry': True,
#    ':-)': True,
#    'yes': True,
#    'back': True,
#    'please': True,
#    'x': True},
#   'Positive'),
#  ({'oh': True,
#    ':(': True,
#    'insurance': True,
#    'loss': True,
#    'steal': True,
#    'accidentally': True,
#    'damage': True,
#    'device': True,
#    'warranty': True,
#    'repair': True,
#    'send': True,
#    'centre': True},
#   'Negative'),
#  ({'malese': True, ':d': True}, 'Positive'),
#  ({'need': True,
#    'get': True,
#    'photo': True,
#    'take': True,
#    'licence': True,
#    'weekend': True,
#    'rly': True,
#    'bad': True,
#    'acne': True,
#    'along': True,
#    'chin': True,
#    'forehead': True,
#    ':(': True},
#   'Negative'),
#  ({"where's": True, 'jaebum': True, 'baby': True, 'picture': True, ':(': True},
#   'Negative'),
#  ({'looking': True,
#    'fun': True,
#    'snapchat': True,
#    'lilybutle': True,
#    '18': True,
#    '#snapchat': True,
#    '#kikmenow': True,
#    '#amateur': True,
#    '#kikmeboys': True,
#    '#seduce': True,
#    '#hannibal': True,
#    '#kiksexting': True,
#    ':(': True},
#   'Negative'),
#  ({"he's": True, 'sleeping': True, 'cute': True, ':-(': True}, 'Negative'),
#  ({'try': True,
#    'burek': True,
#    'meat': True,
#    'gibanica': True,
#    'cheese': True,
#    'pie': True,
#    'breakfast': True,
#    ':)': True},
#   'Positive'),
#  ({'draw': True, ':)': True, '#wip': True, '#sws': True, '#crush': True},
#   'Positive'),
#  ({'well': True,
#    'asleep': True,
#    'one': True,
#    'talk': True,
#    'sooo': True,
#    'someone': True,
#    'text': True,
#    ':)': True},
#   'Positive'),
#  ({'belated': True,
#    'birthday': True,
#    'wish': True,
#    "can't": True,
#    'believe': True,
#    'miss': True,
#    'mind': True,
#    'bdays': True,
#    'inc': True,
#    'bad': True,
#    'phone': True,
#    ':-(': True},
#   'Negative'),
#  ({'welcome': True,
#    'jim': True,
#    'made': True,
#    'chuckle': True,
#    'train': True,
#    'morning': True,
#    ':-)': True,
#    'happy': True,
#    'friday': True},
#   'Positive'),
#  ({'forget': True,
#    'job': True,
#    "i'm": True,
#    'sorry': True,
#    'father': True,
#    ':(': True},
#   'Negative'),
#  ({'fabulous': True,
#    'well': True,
#    'hope': True,
#    'great': True,
#    'day': True,
#    ':-)': True,
#    'kb': True},
#   'Positive'),
#  ({'hi': True,
#    'would': True,
#    'like': True,
#    'concert': True,
#    'let': True,
#    'know': True,
#    'city': True,
#    'country': True,
#    "i'll": True,
#    'start': True,
#    'work': True,
#    'thanks': True,
#    ':)': True},
#   'Positive'),
#  ({'welcome': True, ':)': True}, 'Positive'),
#  ({'oh': True,
#    'good': True,
#    'hear': True,
#    ':(': True,
#    'ask': True,
#    'provide': True,
#    'exactly': True},
#   'Negative'),
#  ({'´': True,
#    'get': True,
#    'chain': True,
#    'love': True,
#    '—': True,
#    'sentir-se': True,
#    'incompleta': True},
#   'Negative'),
#  ({'early': True, 'work': True, ':)': True}, 'Positive'),
#  ({'happy': True,
#    'friday': True,
#    ':)': True,
#    'excite': True,
#    'plan': True,
#    'weekend': True,
#    'winter': True,
#    'ball': True,
#    'falklands': True},
#   'Positive'),
#  ({'ah': True,
#    'good': True,
#    'luck': True,
#    'cat': True,
#    'use': True,
#    'let': True,
#    'go': True,
#    'house': True,
#    'something': True,
#    'play': True,
#    'winter': True,
#    'fast': True,
#    'little': True,
#    'bugger': True,
#    ':(': True},
#   'Negative'),
#  ({'give': True,
#    'work': True,
#    'old': True,
#    'staff': True,
#    'come': True,
#    'police': True,
#    'late': True,
#    'court': True,
#    'look': True,
#    'another': True,
#    'job': True,
#    ':(': True,
#    'bye': True},
#   'Negative'),
#  ({'weak': True, 'dom': True, ':(': True, 'techniques': True}, 'Negative'),
#  ({'perfect': True, ':)': True}, 'Positive'),
#  ({'c': True,
#    '75': True,
#    'make': True,
#    'collagen': True,
#    '#ans2win': True,
#    '#hopetowin': True,
#    ':)': True},
#   'Positive'),
#  ({'loving': True,
#    'buy': True,
#    'one': True,
#    'get': True,
#    'tree': True,
#    'idea': True,
#    ':)': True},
#   'Positive'),
#  ({'phrase': True, 'would': True, 'kind': True, 'way': True, ':(': True},
#   'Negative'),
#  ({"can't": True,
#    'open': True,
#    'door': True,
#    'hard': True,
#    'notice': True,
#    'already': True,
#    'start': True,
#    'song': True,
#    'love': True,
#    'live': True,
#    'fail': True,
#    ':-(': True},
#   'Negative'),
#  ({'enjoy': True,
#    '#londondairy': True,
#    '#icecream': True,
#    'share': True,
#    'us': True,
#    'experience': True,
#    ':)': True},
#   'Positive'),
#  ({'already': True,
#    'sold': True,
#    'like': True,
#    '2': True,
#    'weeks': True,
#    'ago': True,
#    ':(': True},
#   'Negative'),
#  ({'thanks': True,
#    'texting': True,
#    'back': True,
#    ':)': True,
#    "i'm": True,
#    'tomorrow': True},
#   'Positive'),
#  ({'okeyyyyyy': True,
#    'vdddd': True,
#    ':)': True,
#    ');': True,
#    'excited': True,
#    "can't": True,
#    'wait': True,
#    '...': True,
#    'love': True,
#    'selfeeee': True,
#    'pic': True,
#    'insta': True,
#    '♥': True,
#    'special': True,
#    'coco': True,
#    '..': True,
#    '🙆': True,
#    '🙌': True,
#    '😛': True,
#    '😄': True,
#    '😁': True,
#    '😂': True,
#    '🐒': True,
#    '😝': True,
#    '❤': True,
#    '#dishoom': True},
#   'Positive'),
#  ({'bacon': True,
#    'sandwich': True,
#    'marketing': True,
#    'office': True,
#    "i'm": True,
#    'pre-holiday': True,
#    'diet': True,
#    'boooo': True,
#    ':(': True,
#    '#meanies': True,
#    '#deathbybaconsmell': True},
#   'Negative'),
#  ({'retweeted': True, ':)': True}, 'Positive'),
#  ({'supreme': True,
#    'court': True,
#    'even': True,
#    'give': True,
#    'decision': True,
#    'sunny': True,
#    'leon': True,
#    'virgin': True,
#    ':p': True},
#   'Positive'),
#  ({'please': True,
#    'throw': True,
#    'awesome': True,
#    'smile': True,
#    'lilsisbro': True,
#    ':)': True,
#    'hopefully': True,
#    'career': True,
#    'always': True,
#    'success': True},
#   'Positive'),
#  ({'fruity': True, 'vodka': True, 'always': True, 'help': True}, 'Positive'),
#  ({'almost': True,
#    'get': True,
#    'see': True,
#    'cute': True,
#    'ankle': True,
#    'sock': True,
#    ':(': True},
#   'Negative'),
#  ({"that's": True,
#    'completely': True,
#    'true': True,
#    "i'm": True,
#    'watch': True,
#    'entire': True,
#    'series': True,
#    'sg1': True,
#    'right': True,
#    'lightbox': True,
#    'confirm': True,
#    ':)': True},
#   'Positive'),
#  ({'woah': True,
#    'okay': True,
#    'expect': True,
#    'tweet': True,
#    'fucker': True,
#    'die': True,
#    ':)': True},
#   'Positive'),
#  ({'fulfil': True,
#    'fantasy': True,
#    ':)': True,
#    '👉': True,
#    '👈': True,
#    '💖': True},
#   'Positive'),
#  ({':-)': True,
#    'cheers': True,
#    'pete': True,
#    'listen': True,
#    'late': True,
#    '☺': True},
#   'Positive'),
#  ({'bruh': True, ':(': True}, 'Negative'),
#  ({'web': True,
#    'whatsapp': True,
#    'volta': True,
#    'funcionar': True,
#    'com': True,
#    'iphone': True,
#    'jailbroken': True,
#    ':-)': True},
#   'Positive'),
#  ({'sch': True, 'get': True, 'good': True, '...': True, ':-(': True},
#   'Negative'),
#  ({'argh': True,
#    'feel': True,
#    'sick': True,
#    'wish': True,
#    'come': True,
#    'work': True,
#    ':(': True},
#   'Negative'),
#  ({'wish': True,
#    'go': True,
#    'ed': True,
#    'croke': True,
#    'park': True,
#    'today': True,
#    ':(': True},
#   'Negative'),
#  ({'new': True,
#    'product': True,
#    'line': True,
#    '#etsy': True,
#    'shop': True,
#    'check': True,
#    ':)': True,
#    '#boxroomcrafts': True},
#   'Positive'),
#  ({'nba': True,
#    '2k15': True,
#    'mypark': True,
#    '–': True,
#    'chronicles': True,
#    'gryph': True,
#    'volume': True,
#    '3': True,
#    '←': True,
#    'click': True,
#    'aqui': True,
#    ':d': True},
#   'Positive'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({'friday': True, ':)': True}, 'Positive'),
#  ({'dying': True, 'egg': True, 'benny': True, ':(': True}, 'Negative'),
#  ({'unfollow': True, ':(': True}, 'Negative'),
#  ({'great': True,
#    'response': True,
#    'correct': True,
#    'hashtag': True,
#    '#cretaperfectsuv': True,
#    ':)': True,
#    '#cretaperfect4me': True},
#   'Positive'),
#  ({'#zayniscomingbackonjuly26': True,
#    'see': True,
#    'trend': True,
#    'radio': True,
#    'next': True,
#    'sing': True,
#    '...': True,
#    ':(': True},
#   'Negative'),
#  ({'song': True,
#    'fifth': True,
#    'album': True,
#    'notr': True,
#    'ready': True,
#    'hwy': True,
#    'niall': True,
#    'cute': True,
#    ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'far': True,
#    'nightmare': True,
#    'sort': True,
#    ':(': True,
#    'light': True,
#    'end': True,
#    'tunnel': True,
#    'fank': True,
#    'dog': True,
#    'xxx': True},
#   'Negative'),
#  ({'advaddict': True, '_15': True, 'follback': True, 'ya': True, ':)': True},
#   'Positive'),
#  ({':)': True, 'choice': True, 'food': True, 'left': True, 'individual': True},
#   'Positive'),
#  ({'rebound': True,
#    'run': True,
#    'away': True,
#    'already': True,
#    'pooooooooor': True,
#    ':(': True},
#   'Negative'),
#  ({'answering': True,
#    'super': True,
#    'sonically': True,
#    'fast': True,
#    ':)': True,
#    'would': True,
#    'love': True,
#    'win': True,
#    'first': True,
#    'time': True,
#    ';)': True,
#    '#gohf': True},
#   'Positive'),
#  ({'think': True, 'someone': True, 'hack': True, 'acc': True, ':(': True},
#   'Negative'),
#  ({'tile': True,
#    'nice': True,
#    'green': True,
#    'bore': True,
#    'love': True,
#    'original': True,
#    'glass': True,
#    'door': True,
#    'guy': True,
#    'downstairs': True,
#    ':)': True},
#   'Positive'),
#  ({'wish': True,
#    'money': True,
#    'fly': True,
#    'see': True,
#    'concert': True,
#    ':(': True},
#   'Negative'),
#  ({'aww': True,
#    "i've": True,
#    'already': True,
#    'leave': True,
#    'would': True,
#    'come': True,
#    'say': True,
#    'hey': True,
#    'see': True,
#    'sooner': True,
#    ':(': True,
#    'good': True,
#    'night': True,
#    'x': True},
#   'Negative'),
#  ({'follow': True, 'u': True, 'back': True, ':)': True}, 'Positive'),
#  ({"i'll": True,
#    'say': True,
#    'rumble': True,
#    'da': True,
#    'kumble': True,
#    'bc': True,
#    "that's": True,
#    'know': True,
#    ':(': True},
#   'Negative'),
#  ({':(': True, 'vidcon': True}, 'Negative'),
#  ({'neuer': True,
#    'post': True,
#    'online': True,
#    ':)': True,
#    'fixing': True,
#    'spray': True},
#   'Positive'),
#  ({'still': True,
#    'want': True,
#    'harriet': True,
#    'leave': True,
#    'though': True,
#    ':(': True},
#   'Negative'),
#  ({'stop': True, 'buffering': True, ':(': True}, 'Negative'),
#  ({'please': True,
#    'keep': True,
#    'prayer': True,
#    "he's": True,
#    'fragile': True,
#    "can't": True,
#    'even': True,
#    'cry': True,
#    'feel': True,
#    'like': True,
#    "i've": True,
#    'much': True,
#    'week': True,
#    'already': True,
#    ':(': True},
#   'Negative'),
#  ({'guy': True,
#    'estimate': True,
#    'time': True,
#    'server': True,
#    'would': True,
#    ':)': True},
#   'Positive'),
#  ({'aw': True,
#    'sad': True,
#    ':(': True,
#    'long': True,
#    'though': True,
#    'maybe': True,
#    'little': True,
#    'love': True,
#    'restart': True,
#    'assassin': True,
#    'creed': True,
#    'ii': True,
#    'heap': True,
#    'fell': True},
#   'Negative'),
#  ({'also': True, 'want': True, ':(': True}, 'Negative'),
#  ({'hallo': True, ':)': True}, 'Positive'),
#  ({'somewhere': True, 'late': True, ':)': True}, 'Positive'),
#  ({'still': True, 'awake': True, ':)': True}, 'Positive'),
#  ({'sad': True, 'moment': True, 'gon': True, 'vomit': True, ':(': True},
#   'Negative'),
#  ({'west': True,
#    'country': True,
#    'weekend': True,
#    'next': True,
#    'riding': True,
#    'day': True,
#    'tuesday': True,
#    ':)': True,
#    'sunny': True,
#    'around': True},
#   'Positive'),
#  ({'rain': True, 'today': True, 'boo': True, ':(': True}, 'Negative'),
#  ({'yas': True, 'thanks': True, ':)': True, '😊': True}, 'Positive'),
#  ({'filming': True,
#    'day': True,
#    'invite': True,
#    'reason': True,
#    'lol': True,
#    ':)': True},
#   'Positive'),
#  ({'hmmm': True,
#    'always': True,
#    'much': True,
#    'sugar': True,
#    'rarely': True,
#    'make': True,
#    'sorry': True,
#    'help': True,
#    ':(': True},
#   'Negative'),
#  ({'know': True, ':(': True, 'happy': True}, 'Negative'),
#  ({'good': True, 'morning': True}, 'Positive'),
#  ({'glad': True,
#    'one': True,
#    'go': True,
#    'good': True,
#    ':)': True,
#    'make': True,
#    'incredible': True,
#    'beer': True},
#   'Positive'),
#  ({'thank': True, ':-)': True}, 'Positive'),
#  ({'appreciate': True,
#    'follow': True,
#    'like': True,
#    'tweet': True,
#    ':)': True,
#    'dorset': True,
#    'beautiful': True,
#    'place': True},
#   'Positive'),
#  ({'fback': True, ':)': True}, 'Positive'),
#  ({'yup': True,
#    'know': True,
#    'okay': True,
#    'let': True,
#    'try': True,
#    ':)': True,
#    'hhahhaaa': True,
#    '—': True,
#    'haha': True},
#   'Positive'),
#  ({'want': True, 'go': True, "alex's": True, 'house': True, ':(': True},
#   'Negative'),
#  ({'im': True, 'still': True, 'giddy': True, 'd1': True, ':-(': True},
#   'Negative'),
#  ({'grande': True, ':)': True}, 'Positive'),
#  ({'bank': True,
#    'credit': True,
#    'department': True,
#    'bad': True,
#    'enough': True,
#    'anz': True,
#    'go': True,
#    'extreme': True,
#    'offshoring': True,
#    'absolutely': True,
#    'classic': True,
#    ':-)': True,
#    '#gottolovebanks': True},
#   'Positive'),
#  ({"can't": True,
#    'fry': True,
#    'chicken': True,
#    'woe': True,
#    'nigga': True,
#    ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'already': True,
#    'add': True,
#    'please': True,
#    'check': True,
#    'final': True,
#    'design': True,
#    ':)': True},
#   'Positive'),
#  ({'craving': True, 'chicken': True, 'wing': True, ':(': True}, 'Negative'),
#  ({'“': True,
#    'mouth': True,
#    '’': True,
#    'translate': True,
#    'thing': True,
#    'heart': True,
#    'say': True,
#    '”': True,
#    ':(': True},
#   'Negative'),
#  ({'want': True, 'get': True, 'pay': True, 'already': True, ':(': True},
#   'Negative'),
#  ({'excited': True, 'second': True, 'picts': True, ':)': True}, 'Positive'),
#  ({'yes': True,
#    'love': True,
#    'mango': True,
#    'ice': True,
#    'candy': True,
#    '#toothsensitivity': True,
#    'rob': True,
#    'fun': True,
#    'could': True,
#    ':(': True},
#   'Negative'),
#  ({'finally': True,
#    'get': True,
#    'bed': True,
#    ':)': True,
#    'good': True,
#    'night': True,
#    'tweeties': True},
#   'Positive'),
#  ({'iam': True, 'fat': True, ':(': True}, 'Negative'),
#  ({'reckon': True,
#    'chance': True,
#    'see': True,
#    '#t20': True,
#    'action': True,
#    '#taunton': True,
#    'tonight': True,
#    'hopeful': True,
#    'realistic': True,
#    'face': True,
#    ':-(': True},
#   'Negative'),
#  ({'weather': True, 'mad': True, 'work': True, ':(': True, '😒': True},
#   'Negative'),
#  ({'hi': True,
#    'agnes': True,
#    'please': True,
#    'email': True,
#    'socialmedia.co.uk': True,
#    ':)': True,
#    'sam': True},
#   'Positive'),
#  ({':(': True,
#    'hubby': True,
#    'delight': True,
#    'return': True,
#    'home': True,
#    'lol': True},
#   'Negative'),
#  ({':(': True, 'world': True, 'awful': True}, 'Negative'),
#  ({'always': True, 'nice': True, 'get': True, 'invite': True, ':)': True},
#   'Positive'),
#  ({'minho': True,
#    'still': True,
#    'injure': True,
#    ':(': True,
#    'get': True,
#    'well': True,
#    'oppa': True,
#    'miss': True,
#    '<3': True},
#   'Negative'),
#  ({'ek': True, ':)': True, 'want': True, '#ff': True}, 'Positive'),
#  ({'porsche': True,
#    'paddock': True,
#    '#budapestgp': True,
#    'find': True,
#    '#johnyherbert': True,
#    'roll': True,
#    'us': True,
#    'weekend': True,
#    ':)': True,
#    '#porschesupercup': True},
#   'Positive'),
#  ({'hey': True,
#    'like': True,
#    'fnaf': True,
#    'check': True,
#    'youtube': True,
#    'channel': True,
#    ':)': True,
#    'via': True},
#   'Positive'),
#  ({'say': True,
#    'good': True,
#    'kelly': True,
#    'glad': True,
#    'enjoy': True,
#    'nibble': True,
#    ':)': True},
#   'Positive'),
#  ({'way': True, 'common': True, ':-(': True}, 'Negative'),
#  ({'ok': True,
#    '19:30': True,
#    'apple': True,
#    'store': True,
#    'ifc': True,
#    "we'll": True,
#    'pick': True,
#    'place': True,
#    'go': True,
#    ':-)': True},
#   'Positive'),
#  ({'tony': True,
#    'stark': True,
#    ':)': True,
#    'incredible': True,
#    'pictures': True},
#   'Positive'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    ':(': True,
#    'x15': True,
#    '331': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'realize': True,
#    '3': True,
#    'watch': True,
#    'concert': True,
#    'video': True,
#    'pcd': True,
#    'extremely': True,
#    'hard': True,
#    'rn': True,
#    ':(': True},
#   'Negative'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({'chinua': True,
#    'achebe': True,
#    'intellectual': True,
#    'doesnt': True,
#    'mean': True,
#    'know': True,
#    'issue': True,
#    'take': True,
#    'pleasure': True,
#    ':-)': True},
#   'Positive'),
#  ({'please': True, 'leave': True, ':(': True}, 'Negative'),
#  ({'suspect': True,
#    'travel': True,
#    'widely': True,
#    'eventually': True,
#    'return': True,
#    'home': True,
#    'reaapearing': True,
#    'fridge': True,
#    ':-)': True},
#   'Positive'),
#  ({'voucher': True,
#    '...': True,
#    'new': True,
#    'bugatti': True,
#    "what's": True,
#    'value': True,
#    ':d': True},
#   'Positive'),
#  ({'pamer': True, ':)': True}, 'Positive'),
#  ({"i'm": True,
#    'wait': True,
#    'sumer': True,
#    'repackage': True,
#    ":'d": True,
#    'money': True,
#    'buy': True,
#    ':(': True},
#   'Negative'),
#  ({'sum': True, ':(': True}, 'Negative'),
#  ({'#followfriday': True,
#    'top': True,
#    'engage': True,
#    'member': True,
#    'community': True,
#    'week': True,
#    ':)': True},
#   'Positive'),
#  ({'ahm': True,
#    '...': True,
#    "i've": True,
#    'never': True,
#    'london': True,
#    'holiday': True,
#    'outside': True,
#    'ireland': True,
#    'nearly': True,
#    '8': True,
#    'year': True,
#    ':(': True,
#    'get': True,
#    'chance': True,
#    'cash': True,
#    'go': True},
#   'Negative'),
#  ({'want': True, 'one': True, ':(': True}, 'Negative'),
#  ({'please': True,
#    'come': True,
#    'back': True,
#    'love': True,
#    'much': True,
#    '<3': True,
#    ':(': True,
#    '#zayncomebackto1d': True,
#    '#zayniscomingbackonjuly26': True,
#    '#zayniscomingback': True},
#   'Negative'),
#  ({'nfinite': True,
#    'new': True,
#    'update': True,
#    'hoya': True,
#    '#admin_myung': True,
#    'slp': True,
#    ':(': True},
#   'Negative'),
#  ({'stream': True,
#    'say': True,
#    'standby': True,
#    'even': True,
#    'inatall': True,
#    'zenmate': True,
#    ':(': True},
#   'Negative'),
#  ({'guy': True,
#    'really': True,
#    'unlucky': True,
#    'one': True,
#    'driver': True,
#    'briefly': True,
#    'check': True,
#    'egg': True,
#    'half': True,
#    'spot': True},
#   'Negative'),
#  ({'texted': True, 'die': True, 'lurgy': True, 'jim': True, ':(': True},
#   'Negative'),
#  ({'took': True, '11': True, 'hours': True, ':d': True}, 'Positive'),
#  ({'agree': True,
#    'dutch': True,
#    'sound': True,
#    "i'm": True,
#    'sure': True,
#    'legible': True,
#    ':(': True,
#    'israeli': True,
#    'passport': True,
#    'law': True,
#    'return': True},
#   'Negative'),
#  ({'woot': True, 'cool': True, 'peep': True, ':)': True}, 'Positive'),
#  ({'need': True,
#    'ice': True,
#    'cream': True,
#    'lolipop': True,
#    'chocolate': True,
#    'kebab': True,
#    'klappertart': True,
#    'cake': True,
#    'moodboster': True,
#    ':(': True},
#   'Negative'),
#  ({'would': True,
#    "i'm": True,
#    'still': True,
#    'wait': True,
#    'email': True,
#    ':(': True,
#    'check': True,
#    'photo': True},
#   'Negative'),
#  ({'got': True,
#    'acne': True,
#    'day': True,
#    'really': True,
#    'disgust': True,
#    ':(': True},
#   'Negative'),
#  ({'wonderful': True, 'day': True, 'thank': True, ':-)': True}, 'Positive'),
#  ({'thankies': True, ':d': True, 'fuck': True, 'hot': True, 'xx': True},
#   'Positive'),
#  ({'need': True, 'put': True, 'rotation': True, 'lol': True, ':)': True},
#   'Positive'),
# ...
#  ({'oops': True,
#    '...': True,
#    'server': True,
#    'error': True,
#    'occur': True,
#    'email': True,
#    'send': True,
#    ':(': True},
#   'Negative'),
#  ({'...': True,
#    'special': True,
#    'offer': True,
#    'rrp': True,
#    '£': True,
#    '18.99': True,
#    'price': True,
#    '13.99': True,
#    ':)': True},
#   'Positive'),
#  ({'cheers': True, 'realised': True, 'joke': True, ':)': True}, 'Positive'),
#  ({'okay': True, ':)': True}, 'Positive'),
#  ({'ha': True, 'chainsaw': True, ':p': True}, 'Positive'),
#  ({'♛': True,
#    '》': True,
#    'love': True,
#    'much': True,
#    'beli̇eve': True,
#    'wi̇ll': True,
#    'follow': True,
#    'please': True,
#    'justi̇n': True,
#    ':(': True,
#    'x15': True,
#    '349': True,
#    'ｓｅｅ': True,
#    'ｍｅ': True},
#   'Negative'),
#  ({'completely': True,
#    'dodge': True,
#    'explanation': True,
#    'opportunity': True,
#    'thanks': True,
#    'prove': True,
#    'point': True,
#    'grow': True,
#    ':-)': True},
#   'Positive'),
#  ({"today's": True,
#    'arts': True,
#    'craft': True,
#    'session': True,
#    'mehtab': True,
#    'aunty': True,
#    ':)': True},
#   'Positive'),
#  ({'basically': True, 'piss': True, 'cup': True, 'test': True, ':)': True},
#   'Positive'),
#  ({"sacconejoly's": True,
#    'go': True,
#    '...': True,
#    'think': True,
#    "that's": True,
#    ':(': True,
#    'xx': True},
#   'Negative'),
#  ({'miss': True, 'much': True, ':(': True, 'xxxxxx': True}, 'Negative'),
#  ({'paris': True, ':(': True}, 'Negative'),
#  ({'screenshots': True,
#    "there's": True,
#    'competition': True,
#    'open': True,
#    'meet': True,
#    'ariana': True,
#    'grande': True,
#    'country': True,
#    'exclude': True,
#    ':(': True},
#   'Negative'),
#  ({'chaerin': True, 'unnie': True}, 'Positive'),
#  ({'social': True, 'experiment': True, 'make': True, 'cry': True, ':(': True},
#   'Negative'),
#  ({'shady': True,
#    'af': True,
#    'lol': True,
#    'management': True,
#    'say': True,
#    'reservation': True,
#    '11': True,
#    'sept': True,
#    ':)': True},
#   'Positive'),
#  ({'thank': True,
#    'much': True,
#    'mom': True,
#    'getting': True,
#    'tickets': True,
#    ':)': True},
#   'Positive'),
#  ({'see': True,
#    'go': True,
#    ':)': True,
#    'yes': True,
#    'subjective': True,
#    'pain': True,
#    'may': True,
#    'real': True,
#    'make': True,
#    'less': True,
#    'painful': True},
#   'Positive'),
#  ({'hi': True,
#    'bam': True,
#    'follow': True,
#    'bestfriend': True,
#    'love': True,
#    'lot': True,
#    ':)': True,
#    'see': True,
#    'warsaw': True,
#    '<3': True,
#    'x24': True},
#   'Positive'),
#  ({'bowling': True, 'always': True, 'best': True, 'friend': True, ':)': True},
#   'Positive'),
#  ({'live': True,
#    'night': True,
#    'two': True,
#    'fams': True,
#    ':)': True,
#    '#bloodline': True,
#    '#huskies': True},
#   'Positive'),
#  ({'thanks': True,
#    'connect': True,
#    'hope': True,
#    'enjoy': True,
#    'tweet': True,
#    'write': True,
#    'ear': True,
#    '#bebravetoday': True,
#    ':)': True},
#   'Positive'),
#  ({'#ff': True, 'great': True, 'weekend': True, ':)': True}, 'Positive'),
#  ({'real': True,
#    'measure': True,
#    'man': True,
#    'wealth': True,
#    'invest': True,
#    'eternity': True,
#    ':-)': True},
#   'Positive'),
#  ({'yeah': True,
#    'bring': True,
#    'boom': True,
#    "da'esh": True,
#    'co-ord': True,
#    'fsa': True,
#    '#estatic': True,
#    ':)': True},
#   'Positive'),
#  ({':(': True, 'could': True, 'snap': True, 'head': True}, 'Negative'),
#  ({'suk': True,
#    'buttttttt': True,
#    'except': True,
#    'pumpkin': True,
#    'scone': True,
#    '...': True,
#    'havent': True,
#    'make': True,
#    'year': True,
#    ':(': True},
#   'Negative'),
#  ({'sleep': True,
#    'last': True,
#    'night': True,
#    'n': True,
#    'help': True,
#    'wake': True,
#    '8': True,
#    'morning': True,
#    'phone': True,
#    'even': True,
#    'charge': True,
#    ':(': True},
#   'Negative'),
#  ({'waking': True, '...': True, ':(': True}, 'Negative'),
#  ({'minal': True, 'aidzin': True, 'yo': True, 'pi': True, ':d': True},
#   'Positive'),
#  ({'babe': True, 'infront': True, 'tv': True, 'stooooop': True, ':(': True},
#   'Negative'),
#  ({'yep': True,
#    'expert': True,
#    'bisexuality': True,
#    ':)': True,
#    'good': True,
#    'luck': True},
#   'Positive'),
#  ({'yeah': True,
#    ':(': True,
#    'idk': True,
#    'never': True,
#    'find': True,
#    'time': True,
#    'finish': True,
#    'inuyasha': True,
#    "i've": True,
#    'see': True,
#    'lot': True,
#    'anime': True,
#    'grow': True,
#    'watch': True},
#   'Negative'),
#  ({"i'm": True, 'play': True, 'brain': True, 'dots': True, '#braindots': True},
#   'Positive'),
#  ({"i'm": True, 'lonely': True, 'girl': True, 'england': True, ':(': True},
#   'Negative'),
#  ({'short': True,
#    'routine': True,
#    '#quest': True,
#    '#borderlands': True,
#    ':)': True,
#    '#wanderrook': True},
#   'Positive'),
#  ({'new': True, 'still': True, ':)': True}, 'Positive'),
#  ({'jgh': True, 'bond': True, 'niggs': True, ':)': True}, 'Positive'),
#  ({'eh': True,
#    'abuti': True,
#    'welcome': True,
#    'tweetland': True,
#    '...': True,
#    'lol': True,
#    ':p': True},
#   'Positive'),
#  ({'much': True, 'serious': True, 'yun': True, 'eh': True, ':(': True},
#   'Negative'),
#  ({'wish': True, 'could': True, 'join': True, ':(': True}, 'Negative'),
#  ({'mister': True,
#    'best': True,
#    ':)': True,
#    'supportive': True,
#    'kind': True,
#    'absolutely': True,
#    'amazing': True,
#    '3': True},
#   'Positive'),
#  ({'hulk': True,
#    'hogan': True,
#    'news': True,
#    'racial': True,
#    'tirade': True,
#    ':(': True,
#    'think': True,
#    'couldnt': True,
#    'stoop': True,
#    'low': True,
#    'role': True,
#    'thunder': True,
#    'paradise': True},
#   'Negative'),
#  ({'please': True,
#    'follow': True,
#    ':(': True,
#    'wait': True,
#    'back': True,
#    'retweet': True,
#    'reply': True},
#   'Negative'),
#  ({'ahhh': True, 'yes': True, ':d': True}, 'Positive'),
#  ({'cry': True, ':(': True}, 'Negative'),
#  ({'know': True,
#    'right': True,
#    ':(': True,
#    'huhu': True,
#    'sad': True,
#    'lyf': True,
#    '😔': True},
#   'Negative'),
#  ({'want': True, 'escape': True, 'please': True, ':(': True}, 'Negative'),
#  ({'snapchat': True,
#    'abbymill': True,
#    '18': True,
#    '#snapchat': True,
#    '#snapchatme': True,
#    '#wet': True,
#    '#sex': True,
#    '#sexy': True,
#    '#indiemusic': True,
#    '#hotels': True,
#    ':(': True},
#   'Negative'),
#  ({'getting': True,
#    'everything': True,
#    'ready': True,
#    'natural': True,
#    'pefumery': True,
#    'workshop': True,
#    'neals': True,
#    'yard': True,
#    'covent': True,
#    'garden': True,
#    'tomorrow': True,
#    ':)': True},
#   'Positive'),
#  ({'happen': True, 'stop': True, 'talk': True, ':(': True}, 'Negative'),
#  ({'exit': True,
#    'get': True,
#    'maccies': True,
#    'breakfast': True,
#    '10': True,
#    'minute': True,
#    'late': True,
#    'burger': True,
#    'cheese': True,
#    'bite': True,
#    ':(': True},
#   'Negative'),
#  ({':)': True, 'reason': True, 'dream': True, '...': True}, 'Positive'),
#  ({'need': True, 'stress': True, 'time': True, ':)': True}, 'Positive'),
#  ({'huhu': True,
#    'know': True,
#    ':-(': True,
#    'thanks': True,
#    'satya': True,
#    'xx': True},
#   'Negative'),
#  ({'sara': True,
#    'still': True,
#    'speak': True,
#    'occasionally': True,
#    'think': True,
#    "izzy's": True,
#    'leave': True,
#    'twitter': True,
#    ':(': True},
#   'Negative'),
#  ({'isco': True, ':(': True}, 'Negative'),
#  ({'thank': True,
#    'wonderful': True,
#    'reader': True,
#    'like': True,
#    'rose': True,
#    'make': True,
#    'worthwhile': True,
#    'lovely': True,
#    'weekend': True,
#    ':)': True},
#   'Positive'),
#  ({'looking': True,
#    'forward': True,
#    'meet': True,
#    'tower': True,
#    'today': True,
#    ':)': True},
#   'Positive'),
#  ({'someone': True,
#    'bring': True,
#    'sunshine': True,
#    'bob': True,
#    'love': True,
#    'forever': True,
#    '💗': True,
#    ':-)': True},
#   'Positive'),
#  ({'okay': True, ':d': True}, 'Positive'),
#  ({'patch': True, ':(': True}, 'Negative'),
#  ({'much': True, 'brother': True, ':(': True}, 'Negative'),
#  ({'reachability': True,
#    'nc': True,
#    'bug': True,
#    'still': True,
#    'much': True,
#    ':p': True},
#   'Positive'),
#  ({'isis': True, 'chan': True, ':d': True}, 'Positive'),
#  ({'ambrose': True,
#    'gwinett': True,
#    'bierce': True,
#    'world': True,
#    'suffer': True,
#    'ravage': True,
#    'illadvised': True,
#    'marriage': True,
#    'virginity': True,
#    ':)': True},
#   'Positive'),
#  ({'hey': True, 'take': True, 'care': True, ':(': True}, 'Negative'),
#  ({'til': True,
#    '19th': True,
#    'sept': True,
#    'co': True,
#    "that's": True,
#    'bill': True,
#    'start': True,
#    'full': True,
#    'rent': True,
#    ':(': True},
#   'Negative'),
#  ({'yeah': True, ':(': True}, 'Negative'),
#  ({'forgiven': True, 'wonderfuls': True, 'mannerfuls': True, ':)': True},
#   'Positive'),
#  ({'belated': True, 'happy': True, 'bday': True, 'sauce': True, ':)': True},
#   'Positive'),
#  ({'want': True,
#    'shoe': True,
#    'holiday': True,
#    'shipping': True,
#    'take': True,
#    '4-5': True,
#    'day': True,
#    'arrive': True,
#    'today': True,
#    'even': True,
#    'way': True,
#    ':(': True},
#   'Negative'),
#  ({'hit': True,
#    'map': True,
#    'googles': True,
#    'informed': True,
#    'looks': True,
#    'like': True,
#    'quite': True,
#    'pretty': True,
#    'little': True,
#    'place': True,
#    ':)': True},
#   'Positive'),
#  ({'well': True,
#    'gel': True,
#    'know': True,
#    'think': True,
#    '...': True,
#    'yeah': True,
#    'alison': True,
#    'might': True,
#    ':p': True},
#   'Positive'),
#  ({'hot': True,
#    'cornwall': True,
#    'veritably': True,
#    'cold': True,
#    ':(': True,
#    'great': True,
#    'prize': True,
#    'xx': True},
#   'Negative'),
#  ({'sir': True,
#    'wish': True,
#    'detailed': True,
#    'data': True,
#    'available': True,
#    'india': True,
#    ':-)': True},
#   'Positive'),
#  ({'feel': True, 'yah': True, ':(': True}, 'Negative'),
#  ({'listen': True, 'jazz': True, 'truck': True, ':)': True}, 'Positive'),
#  ({'gusto': True,
#    'ko': True,
#    'ng': True,
#    "rodic's": True,
#    ':(': True,
#    'someone': True,
#    'share': True,
#    'order': True,
#    "one's": True,
#    'big': True},
#   'Negative'),
#  ({'one': True,
#    'person': True,
#    'still': True,
#    'important': True,
#    '...': True,
#    'want': True,
#    'go': True,
#    'long': True,
#    'yet': True,
#    'sit': True,
#    'scar': True,
#    'mind': True,
#    ':(': True},
#   'Negative'),
#  ({':(': True, 'wna': True, 'go': True, 'church': True}, 'Negative'),
#  ({'nams': True, 'enjoy': True, 'man': True, ':(': True}, 'Negative'),
#  ({'urgh': True, 'know': True, ':(': True}, 'Negative'),
#  ({'play': True,
#    "blaine's": True,
#    'acoustic': True,
#    'version': True,
#    'teenage': True,
#    'dream': True,
#    'excuse': True,
#    'cry': True,
#    ':(': True},
#   'Negative'),
#  ({'imysm': True, ':(': True}, 'Negative'),
#  ({'feel': True,
#    'like': True,
#    "i'm": True,
#    'weird': True,
#    'person': True,
#    'ship': True,
#    'bellamy': True,
#    'raven': True,
#    'everyone': True,
#    'clarke': True,
#    'heart': True,
#    'want': True,
#    ':(': True},
#   'Negative'),
#  ({'yes': True,
#    'course': True,
#    'pop': True,
#    'email': True,
#    'reservations.eu': True,
#    'date': True,
#    "we'll": True,
#    'get': True,
#    'right': True,
#    'back': True,
#    ':)': True},
#   'Positive'),
#  ({'hate': True,
#    'get': True,
#    'text': True,
#    'look': True,
#    'shift': True,
#    "everyone's": True,
#    'wake': True,
#    ':-(': True},
#   'Negative'),
#  ({'thank': True, ':)': True}, 'Positive'),
#  ({'corner': True,
#    'fucking': True,
#    'dope': True,
#    'getting': True,
#    'addict': True,
#    '..': True,
#    'great': True,
#    'job': True,
#    ':d': True},
#   'Positive'),
#  ({'true': True,
#    'yet': True,
#    'many': True,
#    'know': True,
#    'choose': True,
#    'heed': True,
#    'notion': True,
#    'xx': True,
#    ':(': True},
#   'Negative'),
#  ({'sore': True, 'qt': True, ':(': True}, 'Negative'),
#  ({'ign': True,
#    ':)': True,
#    'au': True,
#    'pubcast': True,
#    '120': True,
#    'hero': True,
#    'deserve': True,
#    'tengaman': True,
#    'tuesday': True,
#    'july': True,
#    '21': True,
#    'celebratio': True,
#    '...': True,
#    '#letsprocrastinate': True},
#   'Positive'),
#  ({'one': True,
#    'dont': True,
#    'see': True,
#    'sinse': True,
#    'trend': True,
#    'something': True,
#    'like': True,
#    'thats': True,
#    ':(': True,
#    '#zayniscomingbackonjuly26': True},
#   'Negative'),
#  ({'good': True, 'girl': True, 'best': True, 'wish': True, ':-)': True},
#   'Positive'),
#  ({'drew': True, ':)': True, 'pls': True}, 'Positive'),
#  ({'sick': True, 'feeling': True, ':(': True, 'wanna': True, 'happpy': True},
#   'Negative'),
#  ({'canadian': True,
#    'family': True,
#    'best': True,
#    'dinner': True,
#    'holiday': True,
#    'last': True,
#    'night': True,
#    'well': True,
#    'enjoyed': True,
#    "we're": True,
#    ':(': True},
#   'Negative'),
#  ({'get': True, 'cupcake': True, '>:(': True}, 'Negative'),
#  ({'dont': True, 'sad': True, ':(': True, 'ily': True}, 'Negative'),
#  ({'4am': True,
#    'right': True,
#    'near': True,
#    'campsite': True,
#    'less': True,
#    'great': True,
#    'kid': True,
#    ':(': True,
#    'total': True,
#    'side': True},
#   'Negative'),
#  ({'back': True,
#    '80s': True,
#    'wz': True,
#    'pattern': True,
#    'cut': True,
#    'make': True,
#    'buttonhole': True,
#    'finishing': True,
#    '4my': True,
#    'designer': True,
#    "friend's": True,
#    'famous': True,
#    'client': True,
#    ':)': True},
#   'Positive'),
#  ({'maybe': True,
#    'get': True,
#    'japanese': True,
#    'import': True,
#    'hello': True,
#    'kitty': True,
#    'matching': True,
#    'stationary': True,
#    ':)': True},
#   'Positive'),
#  ({'cool': True, ':)': True}, 'Positive'),
#  ({'fix': True, 'thanks': True, 'feedback': True, ':)': True}, 'Positive'),
#  ({'sleep': True, 'enough': True, ':(': True}, 'Negative'),
#  ({'happy': True,
#    '15th': True,
#    'birthday': True,
#    'vianey': True,
#    'k': True,
#    'bff': True,
#    ':)': True,
#    '#bffs': True,
#    '#youre15': True,
#    '#july24th': True,
#    '#birthdaygirl': True,
#    ':d': True},
#   'Positive'),
#  ({'say': True, 'icecream': True, 'available': True, ':(': True}, 'Negative'),
#  ({'tbh': True,
#    'bestfriend': True,
#    'breakup': True,
#    'even': True,
#    'bad': True,
#    'relationship': True,
#    ':(': True},
#   'Negative'),
#  ({'yet': True,
#    'finish': True,
#    "i'm": True,
#    'still': True,
#    'season': True,
#    '7': True,
#    ':(': True},
#   'Negative'),
#  ({'ohhh': True,
#    'wait': True,
#    '28': True,
#    ':)': True,
#    'luv': True,
#    'uhh': True},
#   'Positive'),
#  ({'janjua': True, 'friend': True, ':)': True}, 'Positive'),
#  ({'lol': True,
#    '2am': True,
#    'last': True,
#    'night': True,
#    'face': True,
#    'though': True,
#    'people': True,
#    'think': True,
#    "i'm": True,
#    'perpetually': True,
#    'piss': True,
#    'sad': True,
#    'b': True,
#    'c': True,
#    'rest': True,
#    'bitchface': True,
#    ':(': True},
#   'Negative'),
#  ({'eye': True,
#    'really': True,
#    'bad': True,
#    'today': True,
#    'even': True,
#    'glass': True,
#    ':(': True},
#   'Negative'),
#  ({'hate': True, 'break': True, ':(': True}, 'Negative'),
#  ({'enjoy': True, ':)': True}, 'Positive'),
#  ({'celebrate': True,
#    'end': True,
#    'work': True,
#    'week': True,
#    ':)': True,
#    'invite': True,
#    'friend': True,
#    'dine': True,
#    'experience': True,
#    'modern': True,
#    'korean': True,
#    'house': True,
#    '…': True},
#   'Positive'),
#  ({'bad': True, 'news': True, 'day': True, ':(': True}, 'Negative'),
#  ({'oh': True,
#    '#thejuiceinthemix': True,
#    'rela': True,
#    'building': True,
#    ':)': True},
#   'Positive'),
#  ({'someone': True,
#    'harry': True,
#    'potter': True,
#    'marathon': True,
#    ':(': True},
#   'Negative'),
#  ({'welcome': True,
#    'pop': True,
#    'heaven': True,
#    "we're": True,
#    'glad': True,
#    'enjoy': True,
#    ':)': True},
#   'Positive'),
#  ({'get': True, 'well': True, 'soon': True, ':)': True, 'xx': True},
#   'Positive'),
#  ({'hope': True,
#    'bb': True,
#    'get': True,
#    'proper': True,
#    'rest': True,
#    'soon': True,
#    ':(': True},
#   'Negative'),
#  ({'square': True,
#    'enix': True,
#    'bissmillah': True,
#    'ya': True,
#    'allah': True,
#    ':)': True},
#   'Positive'),
#  ({'airport': True, ':(': True}, 'Negative'),
#  ...]

# %%
# from nltk.metrics import ConfusionMatrix
# p = NaiveBayesClassifier.classify(classifier, test_data)
# print(ConfusionMatrix(test_data))

# %%
# cm = nltk.ConfusionMatrix(gold, test)
# print(cm.pretty_format(sort_by_count=True, show_percents=True, truncate=9))

# %%
import pandas as pd
x = pd.DataFrame(train_data)

# %%
y = pd.DataFrame(test_data)

# %%
# from nltk.metrics import ConfusionMatrix

# cm = ConfusionMatrix(train_data[0], test_data[0])
# print(cm)

# %% [markdown]
#      |
#      |      Pos      Neg
# ----+-------------------
#  Pos | <49.18%>  0.92%
#      |
#  Neg |   1.20%  <48.7%>
# (row = reference; col = test)

# %%
import collections
from nltk import precision, f_measure, recall
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')
 
negfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'neg') for f in negids]
posfeats = [(word_feats(movie_reviews.words(fileids=[f])), 'pos') for f in posids]
 
negcutoff = int(len(negfeats)*3/4)
poscutoff = int(len(posfeats)*3/4)
 
trainfeats = negfeats[:negcutoff] + posfeats[:poscutoff]
testfeats = negfeats[negcutoff:] + posfeats[poscutoff:]
print('train on %d instances, test on %d instances' % (len(trainfeats), len(testfeats)))
 
classifier = NaiveBayesClassifier.train(trainfeats)
refsets = collections.defaultdict(set)
testsets = collections.defaultdict(set)
 
for i, (feats, label) in enumerate(testfeats):
    refsets[label].add(i)
    observed = classifier.classify(feats)
    testsets[observed].add(i)
 

print('pos precision:', precision(refsets['pos'], testsets['pos']))
print('pos recall:', recall(refsets['pos'], testsets['pos']))
print('pos F-measure:', f_measure(refsets['pos'], testsets['pos']))
print('neg precision:', precision(refsets['neg'], testsets['neg']))
print('neg recall:', recall(refsets['neg'], testsets['neg']))
print('neg F-measure:', f_measure(refsets['neg'], testsets['neg']))
# Out:
# train on 1500 instances, test on 500 instances
# pos precision: 0.651595744680851
# pos recall: 0.98
# pos F-measure: 0.7827476038338657
# neg precision: 0.9596774193548387
# neg recall: 0.476
# neg F-measure: 0.6363636363636364
